# %%
# Out:
#   Input In [2]
#     impor pandas as pd
#           ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
file = pd.read_csv('banks/AXISBANK.csv')
df = pd.DataFrame(file)
print(df)
# Out:
#            Date  Open Price  High Price  Low Price  Close Price         WAP  \
# 0   9-June-2021      745.00      751.45     730.05       736.55  742.361071
# 1   8-June-2021      750.70      750.70     739.50       746.10  744.763818
# 2   7-June-2021      742.10      753.70     741.35       751.10  742.643818
# 3   4-June-2021      749.60      760.10     740.00       742.10  748.579259
# 4   3-June-2021      743.35      752.00     739.05       750.45  746.603048
# 5   2-June-2021      746.00      746.10     734.20       737.05  737.070943
# 6   1-June-2021      752.30      753.15     741.35       745.10  745.788117
# 7   31-May-2021      740.00      752.85     734.10       750.25  745.285451
# 8   28-May-2021      753.60      759.75     738.35       739.95  749.128474
# 9   27-May-2021      735.20      754.00     731.05       750.25  744.348867
# 10  26-May-2021      737.00      741.30     729.55       735.00  736.951413
# ...
